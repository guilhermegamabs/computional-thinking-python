# %%
import pandas as pd
import numpy as np

# %%
np. random. seed (500)
n = 5000 # Quantidade de registros
df = pd. DataFrame({
    'ID_Transacao': range (1, n+1),
    'Valor': np. random.uniform(10, 10000, n),
    'Tipo_Transacao': np. random.choice(['Compra', 'Transferencia', 'Pagamento'], n),
    'Localizacao': np. random.choice(['SP', 'RJ', 'MG', 'RS', 'BA', 'PR'], n),
    'Horario': np. random.choice(['Manha', 'Tarde', 'Noite', 'Madrugada'], n),
    'Fraude': np.random.choice([0, 1], n, p=[0.7, 0.3])
})
df. head ()
# Out:
#    ID_Transacao        Valor Tipo_Transacao Localizacao Horario  Fraude
# 0             1  6939.858475  Transferencia          PR   Tarde       1
# 1             2   626.552756         Compra          SP   Tarde       1
# 2             3  6669.449857      Pagamento          RS   Tarde       1
# 3             4  5596.497279         Compra          BA   Noite       1
# 4             5   860.255123         Compra          RS   Manha       0

# %%
# Terceiro Exercício
# Dividir a base por localização e realizar amostragem proporcional
localizacao_counts = df['Localizacao'].value_counts()

# fractions[x.name] pega a fração de cada grupo (localização) na população total para garantir que a amostra seja proporcional.
amostra_proporcional = df.groupby('Localizacao', group_keys=False).apply(lambda x: x.sample(frac=localizacao_counts[x.name] / len(df)))
print(amostra_proporcional.head())
# Out:
#       ID_Transacao        Valor Tipo_Transacao Localizacao    Horario  Fraude
# 761            762  7145.209856         Compra          BA  Madrugada       0
# 3519          3520  8857.973438  Transferencia          BA      Noite       0
# 2804          2805  7619.598394         Compra          BA      Tarde       0
# 2106          2107  3928.234340         Compra          BA      Manha       0
# 859            860  8824.536781  Transferencia          BA      Manha       1
# <ipython-input-17-d284cb4f3ca0>:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   amostra_proporcional = df.groupby('Localizacao', group_keys=False).apply(lambda x: x.sample(frac=localizacao_counts[x.name] / len(df)))
